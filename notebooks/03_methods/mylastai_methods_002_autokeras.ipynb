# %%
# !pip3 install pip
# !pip3 install tensorflow==2.1.0
# !pip3 install keras
# !pip3 install autokeras==1.0.2
# Out:
# Requirement already satisfied: pip in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (20.1)
# Requirement already satisfied: tensorflow==2.1.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.14.0)
# Requirement already satisfied: grpcio>=1.8.6 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.28.1)
# Requirement already satisfied: keras-applications>=1.0.8 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (0.2.0)
# Requirement already satisfied: gast==0.2.2 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (0.2.2)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.18.3)
# Requirement already satisfied: protobuf>=3.8.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (3.11.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (3.2.1)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.4.1)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (2.1.1)
# Requirement already satisfied: astor>=0.6.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (0.8.1)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (2.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (0.34.2)
# Requirement already satisfied: wrapt>=1.11.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorflow==2.1.0) (0.9.0)
# Requirement already satisfied: h5py in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow==2.1.0) (2.10.0)
# Requirement already satisfied: setuptools in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from protobuf>=3.8.0->tensorflow==2.1.0) (41.2.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.14.1)
# Requirement already satisfied: requests<3,>=2.21.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.0.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2020.4.5.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.1.0)
# Requirement already satisfied: keras in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.9.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras) (1.18.3)
# Requirement already satisfied: h5py in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras) (1.1.0)
# Requirement already satisfied: pyyaml in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras) (1.14.0)
# Requirement already satisfied: autokeras==1.0.2 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (1.0.2)
# Requirement already satisfied: keras-tuner>=1.0.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from autokeras==1.0.2) (1.0.1)
# Requirement already satisfied: scikit-learn in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from autokeras==1.0.2) (0.22.2.post1)
# Requirement already satisfied: pandas in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from autokeras==1.0.2) (1.0.3)
# Requirement already satisfied: packaging in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from autokeras==1.0.2) (20.3)
# Requirement already satisfied: numpy in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from autokeras==1.0.2) (1.18.3)
# Requirement already satisfied: colorama in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-tuner>=1.0.1->autokeras==1.0.2) (0.4.3)
# Requirement already satisfied: future in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-tuner>=1.0.1->autokeras==1.0.2) (0.18.2)
# Requirement already satisfied: scipy in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-tuner>=1.0.1->autokeras==1.0.2) (1.4.1)
# Requirement already satisfied: tqdm in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-tuner>=1.0.1->autokeras==1.0.2) (4.45.0)
# Requirement already satisfied: terminaltables in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-tuner>=1.0.1->autokeras==1.0.2) (3.1.0)
# Requirement already satisfied: requests in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-tuner>=1.0.1->autokeras==1.0.2) (2.23.0)
# Requirement already satisfied: tabulate in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from keras-tuner>=1.0.1->autokeras==1.0.2) (0.8.7)
# Requirement already satisfied: joblib>=0.11 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from scikit-learn->autokeras==1.0.2) (0.14.1)
# Requirement already satisfied: pytz>=2017.2 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from pandas->autokeras==1.0.2) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from pandas->autokeras==1.0.2) (2.8.1)
# Requirement already satisfied: six in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from packaging->autokeras==1.0.2) (1.14.0)
# Requirement already satisfied: pyparsing>=2.0.2 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from packaging->autokeras==1.0.2) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.1->autokeras==1.0.2) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.1->autokeras==1.0.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.1->autokeras==1.0.2) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./mylastai_0007_methods_autokeras/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.1->autokeras==1.0.2) (1.25.9)

# %%
import autokeras as ak
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-85d187d68977> in <module>
# ----> 1 import autokeras as ak
#
# ModuleNotFoundError: No module named 'autokeras'

# %%
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# (60000, 28, 28)
# (60000,)
# [5 0 4]

# %%
clf = ak.ImageClassifier()
clf.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5e801f72954c> in <module>
#       1 clf = ak.ImageClassifier()
# ----> 2 clf.fit(x_train, y_train,epochs=3)
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/autokeras/tasks/image.py in fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     114             **kwargs: Any arguments supported by keras.Model.fit.
#     115         """
# --> 116         super().fit(x=x,
#     117                     y=y,
#     118                     epochs=epochs,
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/autokeras/auto_model.py in fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, **kwargs)
#     251         dataset = dataset.batch(batch_size)
#     252         validation_data = validation_data.batch(batch_size)
# --> 253         self.tuner.search(x=dataset,
#     254                           epochs=epochs,
#     255                           callbacks=callbacks,
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/autokeras/engine/tuner.py in search(self, callbacks, fit_on_val_data, **fit_kwargs)
#     112             new_callbacks.append(tf.keras.callbacks.EarlyStopping(patience=10))
#     113
# --> 114         super().search(callbacks=new_callbacks, **fit_kwargs)
#     115
#     116         # Fully train the best model with original callbacks.
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/kerastuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     128
#     129             self.on_trial_begin(trial)
# --> 130             self.run_trial(trial, *fit_args, **fit_kwargs)
#     131             self.on_trial_end(trial)
#     132         self.on_search_end()
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/autokeras/engine/tuner.py in run_trial(self, trial, x, *fit_args, **fit_kwargs)
#      69             model = self.hypermodel.build(trial.hyperparameters)
#      70             utils.adapt_model(model, x)
# ---> 71             history = model.fit(x, *fit_args, **copied_fit_kwargs)
#      72             for metric, epoch_values in history.history.items():
#      73                 if self.oracle.objective.direction == 'min':
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     625       # This is the first call of __call__, so we have to initialize.
#     626       initializers = []
# --> 627       self._initialize(args, kwds, add_initializers_to=initializers)
#     628     finally:
#     629       # At this point we know that the initialization is complete (or less
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     503     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     504     self._concrete_stateful_fn = (
# --> 505         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     506             *args, **kwds))
#     507
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2444       args, kwargs = None, None
#    2445     with self._lock:
# -> 2446       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2447     return graph_function
#    2448
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2775
#    2776       self._function_cache.missed.add(call_context_key)
# -> 2777       graph_function = self._create_graph_function(args, kwargs)
#    2778       self._function_cache.primary[cache_key] = graph_function
#    2779       return graph_function, args, kwargs
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2655     arg_names = base_arg_names + missing_arg_names
#    2656     graph_function = ConcreteFunction(
# -> 2657         func_graph_module.func_graph_from_py_func(
#    2658             self._name,
#    2659             self._python_function,
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     979         _, original_func = tf_decorator.unwrap(python_func)
#     980
# --> 981       func_outputs = python_func(*func_args, **func_kwargs)
#     982
#     983       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     439         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     440         # the function a weak reference to itself to avoid a reference cycle.
# --> 441         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     442     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     443
#
# ~/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     966           except Exception as e:  # pylint:disable=broad-except
#     967             if hasattr(e, "ag_error_metadata"):
# --> 968               raise e.ag_error_metadata.to_exception(e)
#     969             else:
#     970               raise
#
# AttributeError: in user code:
#
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:571 train_function  *
#         outputs = self.distribute_strategy.run(
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:951 run  **
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2290 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2649 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:543 train_step  **
#         self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:391 update_state
#         self._build(y_pred, y_true)
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:321 _build
#         self._metrics = nest.map_structure_up_to(y_pred, self._get_metric_objects,
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/util/nest.py:1114 map_structure_up_to
#         return map_structure_with_tuple_paths_up_to(
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/util/nest.py:1213 map_structure_with_tuple_paths_up_to
#         results = [func(*args, **kwargs) for args in zip(flat_path_list,
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/util/nest.py:1213 <listcomp>
#         results = [func(*args, **kwargs) for args in zip(flat_path_list,
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/util/nest.py:1116 <lambda>
#         lambda _, *values: func(*values),  # Discards the path arg.
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:421 _get_metric_objects
#         return [self._get_metric_object(m, y_t, y_p) for m in metrics]
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:421 <listcomp>
#         return [self._get_metric_object(m, y_t, y_p) for m in metrics]
#     /home/backhaus/Entwicklung/mylastai/mylastai_0008_project_handlevideo/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:442 _get_metric_object
#         y_t_rank = len(y_t.shape.as_list())
#
#     AttributeError: 'tuple' object has no attribute 'shape'
